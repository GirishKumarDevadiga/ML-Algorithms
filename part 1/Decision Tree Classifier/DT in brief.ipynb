# %%
import csv
import math

# %%
def load_csv(filename):
    lines=csv.reader(open(filename,"r"));
    dataset = list(lines)
    headers = dataset.pop(0)
    return dataset,headers

# %%
class Node:
    def __init__(self,attribute):
        self.attribute=attribute
        self.children=[]
        self.answer=""

# %%
def subtables(data, col, delete):
    dic = {}
    coldata = [row[col] for row in data]
    attr = list(set(coldata))

    counts = [0] * len(attr)
    r = len(data)
    c = len(data[0])
    for x in range(len(attr)):
        for y in range(r):
            if data[y][col] == attr[x]:
                counts[x] += 1

    for x in range(len(attr)):
        dic[attr[x]] = [[0 for i in range(c)] for j in range(counts[x])]
        pos = 0
        for y in range(r):
            if data[y][col] == attr[x]:
                if delete:
                    del data[y][col]
                dic[attr[x]][pos] = data[y]
                pos += 1
    return attr, dic


def entropy(S):
    attr = list(set(S))
    if len(attr) == 1:
        return 0

    counts = [0, 0]
    for i in range(2):
        counts[i] = sum([1 for x in S if attr[i] == x]) / (len(S) * 1.0)

    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)
    return sums


def compute_gain(data, col):
    attr, dic = subtables(data, col, delete=False)

    total_size = len(data)
    entropies = [0] * len(attr)
    ratio = [0] * len(attr)

    total_entropy = entropy([row[-1] for row in data])

    for x in range(len(attr)):
        ratio[x] = len(dic[attr[x]]) / (total_size * 1.0)
        entropies[x] = entropy([row[-1] for row in dic[attr[x]]])
        total_entropy -= ratio[x] * entropies[x]
    return total_entropy


def build_tree(data, features):
    lastcol = [row[-1] for row in data]
    if (len(set(lastcol))) == 1:
        node = Node("")
        node.answer = lastcol[0]
        return node

    n = len(data[0]) - 1
    gains = [0] * n

    for col in range(n):
        gains[col] = compute_gain(data, col)

    split = gains.index(max(gains))
    node = Node(features[split])
    fea = features[:split] + features[split + 1:]

    attr, dic = subtables(data, split, delete=True)

    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)
        node.children.append((attr[x], child))
    return node


def print_tree(node, level):
    if node.answer != "":
        print(" " * level, node.answer)
        return

    print(" " * level, node.attribute)

    for value, n in node.children:
        print(" " * (level + 1), value)
        print_tree(n, level + 2)


def classify(node, x_test, features):
    if node.answer != "":
        print(node.answer)
        return

    pos = features.index(node.attribute)

    for value, n in node.children:
        if x_test[pos] == value:
            classify(n, x_test, features)

# %%
'''Main program'''
dataset,features=load_csv("Social_Network_Ads.csv")
node1=build_tree(dataset,features)

# %%
print("The decision tree for the dataset using ID3 algorithm is")
print_tree(node1,0)
testdata,features=load_csv("Social_Network_Ads.csv")
# Out:
# The decision tree for the dataset using ID3 algorithm is
#  User ID
#   15776733
#    0
#   15584320
#    1
#   15694879
#    1
#   15792008
#    0
#   15727696
#    1
#   15807837
#    1
#   15807909
#    0
#   15577514
#    1
#   15697020
#    0
#   15638963
#    0
#   15711218
#    0
#   15755018
#    0
#   15789863
#    0
#   15764604
#    1
#   15782530
#    0
#   15688172
#    1
#   15699247
#    0
#   15708196
#    0
#   15766289
#    0
#   15595917
#    0
#   15809347
#    0
#   15715541
#    0
#   15582066
#    0
#   15668521
#    1
#   15694395
#    0
#   15800061
#    0
#   15693264
#    0
#   15674206
#    0
#   15663161
#    1
#   15672330
#    1
#   15750056
#    1
#   15617482
#    1
#   15791373
#    1
#   15678168
#    0
#   15741049
#    0
#   15625395
#    1
#   15767871
#    0
#   15631912
#    0
#   15723373
#    0
#   15793813
#    0
#   15720745
#    1
#   15753102
#    1
#   15697574
#    0
#   15574305
#    0
#   15578006
#    0
#   15624510
#    0
#   15646091
#    1
#   15753861
#    1
#   15628972
#    0
#   15778830
#    1
#   15636428
#    0
#   15813113
#    1
#   15603246
#    0
#   15675949
#    1
#   15801247
#    0
#   15744279
#    1
#   15779529
#    1
#   15748589
#    1
#   15697997
#    0
#   15575694
#    0
#   15689425
#    0
#   15721007
#    1
#   15642725
#    0
#   15753874
#    0
#   15713144
#    0
#   15619465
#    1
#   15663249
#    1
#   15727311
#    0
#   15591915
#    0
#   15796351
#    1
#   15746139
#    0
#   15679297
#    0
#   15614827
#    0
#   15792818
#    1
#   15574372
#    1
#   15733973
#    1
#   15725660
#    0
#   15584545
#    0
#   15673367
#    0
#   15660866
#    1
#   15617877
#    0
#   15583681
#    1
#   15581282
#    0
#   15649136
#    0
#   15593715
#    1
#   15612465
#    0
#   15667417
#    1
#   15594041
#    1
#   15586757
#    1
#   15757837
#    0
#   15579781
#    0
#   15722061
#    1
#   15701962
#    0
#   15592570
#    1
#   15791174
#    0
#   15716781
#    0
#   15687491
#    1
#   15671766
#    0
#   15581198
#    0
#   15666675
#    0
#   15667265
#    0
#   15787550
#    0
#   15814004
#    0
#   15806901
#    1
#   15745083
#    0
#   15689237
#    0
#   15594577
#    0
#   15735878
#    1
#   15750447
#    1
#   15747043
#    1
#   15794661
#    0
#   15695679
#    0
#   15691808
#    0
#   15774179
#    0
#   15738448
#    0
#   15779862
#    0
#   15730448
#    0
#   15654230
#    1
#   15720943
#    0
#   15810944
#    0
#   15789109
#    0
#   15654574
#    0
#   15810800
#    0
#   15577178
#    0
#   15722758
#    0
#   15613014
#    1
#   15724536
#    1
#   15577806
#    1
#   15638646
#    0
#   15683758
#    0
#   15598840
#    1
#   15622585
#    1
#   15733964
#    0
#   15566689
#    0
#   15668385
#    0
#   15588080
#    1
#   15611191
#    1
#   15776844
#    0
#   15609637
#    0
#   15727467
#    1
#   15706071
#    1
#   15724402
#    0
#   15602373
#    0
#   15694453
#    0
#   15599533
#    0
#   15705113
#    1
#   15704583
#    1
#   15713463
#    0
#   15747097
#    0
#   15769902
#    0
#   15621083
#    1
#   15780572
#    1
#   15794253
#    1
#   15587177
#    0
#   15663939
#    1
#   15741094
#    0
#   15622833
#    0
#   15694829
#    1
#   15660541
#    0
#   15782806
#    0
#   15690188
#    0
#   15600379
#    1
#   15756820
#    0
#   15713912
#    1
#   15807525
#    1
#   15573452
#    0
#   15603319
#    0
#   15772073
#    1
#   15750335
#    0
#   15792102
#    0
#   15611430
#    1
#   15665760
#    1
#   15646227
#    1
#   15637593
#    1
#   15614187
#    1
#   15724161
#    0
#   15587013
#    0
#   15749381
#    1
#   15729054
#    1
#   15665416
#    0
#   15606274
#    0
#   15724150
#    1
#   15599081
#    1
#   15697686
#    0
#   15699284
#    0
#   15624755
#    1
#   15779744
#    0
#   15726358
#    0
#   15570932
#    0
#   15619087
#    0
#   15606472
#    1
#   15708228
#    0
#   15684861
#    0
#   15685346
#    1
#   15745232
#    0
#   15619407
#    0
#   15652400
#    0
#   15600575
#    0
#   15744529
#    0
#   15671655
#    0
#   15619653
#    0
#   15744919
#    0
#   15662067
#    0
#   15570769
#    0
#   15717893
#    0
#   15594762
#    1
#   15707596
#    0
#   15774744
#    1
#   15705298
#    1
#   15631070
#    0
#   15724423
#    0
#   15795224
#    1
#   15774727
#    0
#   15589449
#    1
#   15710257
#    0
#   15589715
#    1
#   15587419
#    1
#   15666141
#    0
#   15654901
#    0
#   15571059
#    0
#   15673539
#    1
#   15671249
#    1
#   15692819
#    1
#   15725794
#    0
#   15596984
#    0
#   15691863
#    1
#   15694288
#    1
#   15573926
#    1
#   15623502
#    0
#   15794566
#    0
#   15746737
#    0
#   15774872
#    1
#   15789432
#    0
#   15609669
#    1
#   15785170
#    0
#   15682268
#    0
#   15757632
#    0
#   15736397
#    1
#   15670619
#    0
#   15674331
#    0
#   15694946
#    0
#   15603942
#    0
#   15789815
#    1
#   15756932
#    0
#   15622171
#    0
#   15673619
#    0
#   15728773
#    0
#   15680243
#    0
#   15586996
#    0
#   15801336
#    1
#   15810075
#    0
#   15605000
#    0
#   15804002
#    0
#   15610801
#    0
#   15595135
#    0
#   15815236
#    1
#   15592877
#    0
#   15670615
#    1
#   15668504
#    0
#   15646936
#    1
#   15639277
#    0
#   15759684
#    1
#   15678201
#    1
#   15697424
#    0
#   15610140
#    0
#   15768816
#    0
#   15667742
#    0
#   15739160
#    0
#   15779581
#    0
#   15762605
#    0
#   15581654
#    0
#   15579212
#    0
#   15721592
#    0
#   15717560
#    0
#   15767681
#    0
#   15709476
#    0
#   15794493
#    0
#   15701537
#    1
#   15636023
#    0
#   15598070
#    0
#   15575247
#    1
#   15742204
#    1
#   15675791
#    0
#   15679760
#    0
#   15773447
#    0
#   15689751
#    0
#   15707634
#    1
#   15809823
#    0
#   15639576
#    1
#   15672821
#    1
#   15746203
#    1
#   15654296
#    1
#   15715160
#    0
#   15569641
#    1
#   15736228
#    0
#   15746422
#    0
#   15783029
#    0
#   15629885
#    0
#   15657163
#    0
#   15662901
#    0
#   15655123
#    0
#   15759066
#    0
#   15622478
#    0
#   15680752
#    0
#   15800890
#    1
#   15801658
#    0
#   15786993
#    0
#   15760570
#    0
#   15583137
#    0
#   15633531
#    1
#   15769596
#    1
#   15635893
#    1
#   15596522
#    1
#   15775590
#    1
#   15644296
#    0
#   15807481
#    0
#   15750839
#    1
#   15649487
#    1
#   15811613
#    0
#   15628523
#    0
#   15729908
#    1
#   15679651
#    0
#   15734161
#    1
#   15591433
#    0
#   15732987
#    1
#   15775562
#    0
#   15671387
#    0
#   15811177
#    0
#   15629739
#    1
#   15672091
#    0
#   15595228
#    0
#   15605327
#    0
#   15714658
#    1
#   15627220
#    0
#   15814816
#    0
#   15768151
#    1
#   15766609
#    0
#   15764419
#    0
#   15595324
#    0
#   15651983
#    1
#   15795298
#    1
#   15680587
#    1
#   15609653
#    0
#   15614420
#    0
#   15582492
#    1
#   15762228
#    0
#   15778368
#    1
#   15768072
#    1
#   15631159
#    1
#   15709183
#    0
#   15749130
#    0
#   15724858
#    0
#   15699619
#    1
#   15575002
#    0
#   15709441
#    0
#   15685536
#    0
#   15601550
#    0
#   15715622
#    1
#   15598044
#    0
#   15736760
#    1
#   15706185
#    0
#   15721835
#    0
#   15768293
#    0
#   15675185
#    0
#   15684801
#    0
#   15617134
#    0
#   15654456
#    1
#   15735549
#    1
#   15800515
#    1
#   15638003
#    0
#   15761950
#    1
#   15596761
#    1
#   15708791
#    1
#   15718071
#    0
#   15610403
#    0
#   15776348
#    0
#   15730688
#    0
#   15578738
#    0
#   15669656
#    0
#   15793890
#    0
#   15685576
#    0
#   15591279
#    0
#   15800215
#    0
#   15642885
#    0
#   15798850
#    0
#   15584114
#    0
#   15649668
#    0
#   15668575
#    0
#   15764195
#    0
#   15704987
#    0
#   15734312
#    0
#   15664907
#    1
#   15576219
#    0
#   15814553
#    1
#   15798659
#    0
#   15772798
#    0
#   15775335
#    1
#   15593014
#    0
#   15733883
#    1
#   15660200
#    0

# %%
for xtest in testdata:
    print("The test instance:",xtest)
    print("The label for test instance:",end=" ")
    classify(node1,xtest,features)
# Out:
# The test instance: ['15624510', 'Male', '19', '19000', '0']
# The label for test instance: 0
# The test instance: ['15810944', 'Male', '35', '20000', '0']
# The label for test instance: 0
# The test instance: ['15668575', 'Female', '26', '43000', '0']
# The label for test instance: 0
# The test instance: ['15603246', 'Female', '27', '57000', '0']
# The label for test instance: 0
# The test instance: ['15804002', 'Male', '19', '76000', '0']
# The label for test instance: 0
# The test instance: ['15728773', 'Male', '27', '58000', '0']
# The label for test instance: 0
# The test instance: ['15598044', 'Female', '27', '84000', '0']
# The label for test instance: 0
# The test instance: ['15694829', 'Female', '32', '150000', '1']
# The label for test instance: 1
# The test instance: ['15600575', 'Male', '25', '33000', '0']
# The label for test instance: 0
# The test instance: ['15727311', 'Female', '35', '65000', '0']
# The label for test instance: 0
# The test instance: ['15570769', 'Female', '26', '80000', '0']
# The label for test instance: 0
# The test instance: ['15606274', 'Female', '26', '52000', '0']
# The label for test instance: 0
# The test instance: ['15746139', 'Male', '20', '86000', '0']
# The label for test instance: 0
# The test instance: ['15704987', 'Male', '32', '18000', '0']
# The label for test instance: 0
# The test instance: ['15628972', 'Male', '18', '82000', '0']
# The label for test instance: 0
# The test instance: ['15697686', 'Male', '29', '80000', '0']
# The label for test instance: 0
# The test instance: ['15733883', 'Male', '47', '25000', '1']
# The label for test instance: 1
# The test instance: ['15617482', 'Male', '45', '26000', '1']
# The label for test instance: 1
# The test instance: ['15704583', 'Male', '46', '28000', '1']
# The label for test instance: 1
# The test instance: ['15621083', 'Female', '48', '29000', '1']
# The label for test instance: 1
# The test instance: ['15649487', 'Male', '45', '22000', '1']
# The label for test instance: 1
# The test instance: ['15736760', 'Female', '47', '49000', '1']
# The label for test instance: 1
# The test instance: ['15714658', 'Male', '48', '41000', '1']
# The label for test instance: 1
# The test instance: ['15599081', 'Female', '45', '22000', '1']
# The label for test instance: 1
# The test instance: ['15705113', 'Male', '46', '23000', '1']
# The label for test instance: 1
# The test instance: ['15631159', 'Male', '47', '20000', '1']
# The label for test instance: 1
# The test instance: ['15792818', 'Male', '49', '28000', '1']
# The label for test instance: 1
# The test instance: ['15633531', 'Female', '47', '30000', '1']
# The label for test instance: 1
# The test instance: ['15744529', 'Male', '29', '43000', '0']
# The label for test instance: 0
# The test instance: ['15669656', 'Male', '31', '18000', '0']
# The label for test instance: 0
# The test instance: ['15581198', 'Male', '31', '74000', '0']
# The label for test instance: 0
# The test instance: ['15729054', 'Female', '27', '137000', '1']
# The label for test instance: 1
# The test instance: ['15573452', 'Female', '21', '16000', '0']
# The label for test instance: 0
# The test instance: ['15776733', 'Female', '28', '44000', '0']
# The label for test instance: 0
# The test instance: ['15724858', 'Male', '27', '90000', '0']
# The label for test instance: 0
# The test instance: ['15713144', 'Male', '35', '27000', '0']
# The label for test instance: 0
# The test instance: ['15690188', 'Female', '33', '28000', '0']
# The label for test instance: 0
# The test instance: ['15689425', 'Male', '30', '49000', '0']
# The label for test instance: 0
# The test instance: ['15671766', 'Female', '26', '72000', '0']
# The label for test instance: 0
# The test instance: ['15782806', 'Female', '27', '31000', '0']
# The label for test instance: 0
# The test instance: ['15764419', 'Female', '27', '17000', '0']
# The label for test instance: 0
# The test instance: ['15591915', 'Female', '33', '51000', '0']
# The label for test instance: 0
# The test instance: ['15772798', 'Male', '35', '108000', '0']
# The label for test instance: 0
# The test instance: ['15792008', 'Male', '30', '15000', '0']
# The label for test instance: 0
# The test instance: ['15715541', 'Female', '28', '84000', '0']
# The label for test instance: 0
# The test instance: ['15639277', 'Male', '23', '20000', '0']
# The label for test instance: 0
# The test instance: ['15798850', 'Male', '25', '79000', '0']
# The label for test instance: 0
# The test instance: ['15776348', 'Female', '27', '54000', '0']
# The label for test instance: 0
# The test instance: ['15727696', 'Male', '30', '135000', '1']
# The label for test instance: 1
# The test instance: ['15793813', 'Female', '31', '89000', '0']
# The label for test instance: 0
# The test instance: ['15694395', 'Female', '24', '32000', '0']
# The label for test instance: 0
# The test instance: ['15764195', 'Female', '18', '44000', '0']
# The label for test instance: 0
# The test instance: ['15744919', 'Female', '29', '83000', '0']
# The label for test instance: 0
# The test instance: ['15671655', 'Female', '35', '23000', '0']
# The label for test instance: 0
# The test instance: ['15654901', 'Female', '27', '58000', '0']
# The label for test instance: 0
# The test instance: ['15649136', 'Female', '24', '55000', '0']
# The label for test instance: 0
# The test instance: ['15775562', 'Female', '23', '48000', '0']
# The label for test instance: 0
# The test instance: ['15807481', 'Male', '28', '79000', '0']
# The label for test instance: 0
# The test instance: ['15642885', 'Male', '22', '18000', '0']
# The label for test instance: 0
# The test instance: ['15789109', 'Female', '32', '117000', '0']
# The label for test instance: 0
# The test instance: ['15814004', 'Male', '27', '20000', '0']
# The label for test instance: 0
# The test instance: ['15673619', 'Male', '25', '87000', '0']
# The label for test instance: 0
# The test instance: ['15595135', 'Female', '23', '66000', '0']
# The label for test instance: 0
# The test instance: ['15583681', 'Male', '32', '120000', '1']
# The label for test instance: 1
# The test instance: ['15605000', 'Female', '59', '83000', '0']
# The label for test instance: 0
# The test instance: ['15718071', 'Male', '24', '58000', '0']
# The label for test instance: 0
# The test instance: ['15679760', 'Male', '24', '19000', '0']
# The label for test instance: 0
# The test instance: ['15654574', 'Female', '23', '82000', '0']
# The label for test instance: 0
# The test instance: ['15577178', 'Female', '22', '63000', '0']
# The label for test instance: 0
# The test instance: ['15595324', 'Female', '31', '68000', '0']
# The label for test instance: 0
# The test instance: ['15756932', 'Male', '25', '80000', '0']
# The label for test instance: 0
# The test instance: ['15726358', 'Female', '24', '27000', '0']
# The label for test instance: 0
# The test instance: ['15595228', 'Female', '20', '23000', '0']
# The label for test instance: 0
# The test instance: ['15782530', 'Female', '33', '113000', '0']
# The label for test instance: 0
# The test instance: ['15592877', 'Male', '32', '18000', '0']
# The label for test instance: 0
# The test instance: ['15651983', 'Male', '34', '112000', '1']
# The label for test instance: 1
# The test instance: ['15746737', 'Male', '18', '52000', '0']
# The label for test instance: 0
# The test instance: ['15774179', 'Female', '22', '27000', '0']
# The label for test instance: 0
# The test instance: ['15667265', 'Female', '28', '87000', '0']
# The label for test instance: 0
# The test instance: ['15655123', 'Female', '26', '17000', '0']
# The label for test instance: 0
# The test instance: ['15595917', 'Male', '30', '80000', '0']
# The label for test instance: 0
# The test instance: ['15668385', 'Male', '39', '42000', '0']
# The label for test instance: 0
# The test instance: ['15709476', 'Male', '20', '49000', '0']
# The label for test instance: 0
# The test instance: ['15711218', 'Male', '35', '88000', '0']
# The label for test instance: 0
# The test instance: ['15798659', 'Female', '30', '62000', '0']
# The label for test instance: 0
# The test instance: ['15663939', 'Female', '31', '118000', '1']
# The label for test instance: 1
# The test instance: ['15694946', 'Male', '24', '55000', '0']
# The label for test instance: 0
# The test instance: ['15631912', 'Female', '28', '85000', '0']
# The label for test instance: 0
# The test instance: ['15768816', 'Male', '26', '81000', '0']
# The label for test instance: 0
# The test instance: ['15682268', 'Male', '35', '50000', '0']
# The label for test instance: 0
# The test instance: ['15684801', 'Male', '22', '81000', '0']
# The label for test instance: 0
# The test instance: ['15636428', 'Female', '30', '116000', '0']
# The label for test instance: 0
# The test instance: ['15809823', 'Male', '26', '15000', '0']
# The label for test instance: 0
# The test instance: ['15699284', 'Female', '29', '28000', '0']
# The label for test instance: 0
# The test instance: ['15786993', 'Female', '29', '83000', '0']
# The label for test instance: 0
# The test instance: ['15709441', 'Female', '35', '44000', '0']
# The label for test instance: 0
# The test instance: ['15710257', 'Female', '35', '25000', '0']
# The label for test instance: 0
# The test instance: ['15582492', 'Male', '28', '123000', '1']
# The label for test instance: 1
# The test instance: ['15575694', 'Male', '35', '73000', '0']
# The label for test instance: 0
# The test instance: ['15756820', 'Female', '28', '37000', '0']
# The label for test instance: 0
# The test instance: ['15766289', 'Male', '27', '88000', '0']
# The label for test instance: 0
# The test instance: ['15593014', 'Male', '28', '59000', '0']
# The label for test instance: 0
# The test instance: ['15584545', 'Female', '32', '86000', '0']
# The label for test instance: 0
# The test instance: ['15675949', 'Female', '33', '149000', '1']
# The label for test instance: 1
# The test instance: ['15672091', 'Female', '19', '21000', '0']
# The label for test instance: 0
# The test instance: ['15801658', 'Male', '21', '72000', '0']
# The label for test instance: 0
# The test instance: ['15706185', 'Female', '26', '35000', '0']
# The label for test instance: 0
# The test instance: ['15789863', 'Male', '27', '89000', '0']
# The label for test instance: 0
# The test instance: ['15720943', 'Male', '26', '86000', '0']
# The label for test instance: 0
# The test instance: ['15697997', 'Female', '38', '80000', '0']
# The label for test instance: 0
# The test instance: ['15665416', 'Female', '39', '71000', '0']
# The label for test instance: 0
# The test instance: ['15660200', 'Female', '37', '71000', '0']
# The label for test instance: 0
# The test instance: ['15619653', 'Male', '38', '61000', '0']
# The label for test instance: 0
# The test instance: ['15773447', 'Male', '37', '55000', '0']
# The label for test instance: 0
# The test instance: ['15739160', 'Male', '42', '80000', '0']
# The label for test instance: 0
# The test instance: ['15689237', 'Male', '40', '57000', '0']
# The label for test instance: 0
# The test instance: ['15679297', 'Male', '35', '75000', '0']
# The label for test instance: 0
# The test instance: ['15591433', 'Male', '36', '52000', '0']
# The label for test instance: 0
# The test instance: ['15642725', 'Male', '40', '59000', '0']
# The label for test instance: 0
# The test instance: ['15701962', 'Male', '41', '59000', '0']
# The label for test instance: 0
# The test instance: ['15811613', 'Female', '36', '75000', '0']
# The label for test instance: 0
# The test instance: ['15741049', 'Male', '37', '72000', '0']
# The label for test instance: 0
# The test instance: ['15724423', 'Female', '40', '75000', '0']
# The label for test instance: 0
# The test instance: ['15574305', 'Male', '35', '53000', '0']
# The label for test instance: 0
# The test instance: ['15678168', 'Female', '41', '51000', '0']
# The label for test instance: 0
# The test instance: ['15697020', 'Female', '39', '61000', '0']
# The label for test instance: 0
# The test instance: ['15610801', 'Male', '42', '65000', '0']
# The label for test instance: 0
# The test instance: ['15745232', 'Male', '26', '32000', '0']
# The label for test instance: 0
# The test instance: ['15722758', 'Male', '30', '17000', '0']
# The label for test instance: 0
# The test instance: ['15792102', 'Female', '26', '84000', '0']
# The label for test instance: 0
# The test instance: ['15675185', 'Male', '31', '58000', '0']
# The label for test instance: 0
# The test instance: ['15801247', 'Male', '33', '31000', '0']
# The label for test instance: 0
# The test instance: ['15725660', 'Male', '30', '87000', '0']
# The label for test instance: 0
# The test instance: ['15638963', 'Female', '21', '68000', '0']
# The label for test instance: 0
# The test instance: ['15800061', 'Female', '28', '55000', '0']
# The label for test instance: 0
# The test instance: ['15578006', 'Male', '23', '63000', '0']
# The label for test instance: 0
# The test instance: ['15668504', 'Female', '20', '82000', '0']
# The label for test instance: 0
# The test instance: ['15687491', 'Male', '30', '107000', '1']
# The label for test instance: 1
# The test instance: ['15610403', 'Female', '28', '59000', '0']
# The label for test instance: 0
# The test instance: ['15741094', 'Male', '19', '25000', '0']
# The label for test instance: 0
# The test instance: ['15807909', 'Male', '19', '85000', '0']
# The label for test instance: 0
# The test instance: ['15666141', 'Female', '18', '68000', '0']
# The label for test instance: 0
# The test instance: ['15617134', 'Male', '35', '59000', '0']
# The label for test instance: 0
# The test instance: ['15783029', 'Male', '30', '89000', '0']
# The label for test instance: 0
# The test instance: ['15622833', 'Female', '34', '25000', '0']
# The label for test instance: 0
# The test instance: ['15746422', 'Female', '24', '89000', '0']
# The label for test instance: 0
# The test instance: ['15750839', 'Female', '27', '96000', '1']
# The label for test instance: 1
# The test instance: ['15749130', 'Female', '41', '30000', '0']
# The label for test instance: 0
# The test instance: ['15779862', 'Male', '29', '61000', '0']
# The label for test instance: 0
# The test instance: ['15767871', 'Male', '20', '74000', '0']
# The label for test instance: 0
# The test instance: ['15679651', 'Female', '26', '15000', '0']
# The label for test instance: 0
# The test instance: ['15576219', 'Male', '41', '45000', '0']
# The label for test instance: 0
# The test instance: ['15699247', 'Male', '31', '76000', '0']
# The label for test instance: 0
# The test instance: ['15619087', 'Female', '36', '50000', '0']
# The label for test instance: 0
# The test instance: ['15605327', 'Male', '40', '47000', '0']
# The label for test instance: 0
# The test instance: ['15610140', 'Female', '31', '15000', '0']
# The label for test instance: 0
# The test instance: ['15791174', 'Male', '46', '59000', '0']
# The label for test instance: 0
# The test instance: ['15602373', 'Male', '29', '75000', '0']
# The label for test instance: 0
# The test instance: ['15762605', 'Male', '26', '30000', '0']
# The label for test instance: 0
# The test instance: ['15598840', 'Female', '32', '135000', '1']
# The label for test instance: 1
# The test instance: ['15744279', 'Male', '32', '100000', '1']
# The label for test instance: 1
# The test instance: ['15670619', 'Male', '25', '90000', '0']
# The label for test instance: 0
# The test instance: ['15599533', 'Female', '37', '33000', '0']
# The label for test instance: 0
# The test instance: ['15757837', 'Male', '35', '38000', '0']
# The label for test instance: 0
# The test instance: ['15697574', 'Female', '33', '69000', '0']
# The label for test instance: 0
# The test instance: ['15578738', 'Female', '18', '86000', '0']
# The label for test instance: 0
# The test instance: ['15762228', 'Female', '22', '55000', '0']
# The label for test instance: 0
# The test instance: ['15614827', 'Female', '35', '71000', '0']
# The label for test instance: 0
# The test instance: ['15789815', 'Male', '29', '148000', '1']
# The label for test instance: 1
# The test instance: ['15579781', 'Female', '29', '47000', '0']
# The label for test instance: 0
# The test instance: ['15587013', 'Male', '21', '88000', '0']
# The label for test instance: 0
# The test instance: ['15570932', 'Male', '34', '115000', '0']
# The label for test instance: 0
# The test instance: ['15794661', 'Female', '26', '118000', '0']
# The label for test instance: 0
# The test instance: ['15581654', 'Female', '34', '43000', '0']
# The label for test instance: 0
# The test instance: ['15644296', 'Female', '34', '72000', '0']
# The label for test instance: 0
# The test instance: ['15614420', 'Female', '23', '28000', '0']
# The label for test instance: 0
# The test instance: ['15609653', 'Female', '35', '47000', '0']
# The label for test instance: 0
# The test instance: ['15594577', 'Male', '25', '22000', '0']
# The label for test instance: 0
# The test instance: ['15584114', 'Male', '24', '23000', '0']
# The label for test instance: 0
# The test instance: ['15673367', 'Female', '31', '34000', '0']
# The label for test instance: 0
# The test instance: ['15685576', 'Male', '26', '16000', '0']
# The label for test instance: 0
# The test instance: ['15774727', 'Female', '31', '71000', '0']
# The label for test instance: 0
# The test instance: ['15694288', 'Female', '32', '117000', '1']
# The label for test instance: 1
# The test instance: ['15603319', 'Male', '33', '43000', '0']
# The label for test instance: 0
# The test instance: ['15759066', 'Female', '33', '60000', '0']
# The label for test instance: 0
# The test instance: ['15814816', 'Male', '31', '66000', '0']
# The label for test instance: 0
# The test instance: ['15724402', 'Female', '20', '82000', '0']
# The label for test instance: 0
# The test instance: ['15571059', 'Female', '33', '41000', '0']
# The label for test instance: 0
# The test instance: ['15674206', 'Male', '35', '72000', '0']
# The label for test instance: 0
# The test instance: ['15715160', 'Male', '28', '32000', '0']
# The label for test instance: 0
# The test instance: ['15730448', 'Male', '24', '84000', '0']
# The label for test instance: 0
# The test instance: ['15662067', 'Female', '19', '26000', '0']
# The label for test instance: 0
# The test instance: ['15779581', 'Male', '29', '43000', '0']
# The label for test instance: 0
# The test instance: ['15662901', 'Male', '19', '70000', '0']
# The label for test instance: 0
# The test instance: ['15689751', 'Male', '28', '89000', '0']
# The label for test instance: 0
# The test instance: ['15667742', 'Male', '34', '43000', '0']
# The label for test instance: 0
# The test instance: ['15738448', 'Female', '30', '79000', '0']
# The label for test instance: 0
# The test instance: ['15680243', 'Female', '20', '36000', '0']
# The label for test instance: 0
# The test instance: ['15745083', 'Male', '26', '80000', '0']
# The label for test instance: 0
# The test instance: ['15708228', 'Male', '35', '22000', '0']
# The label for test instance: 0
# The test instance: ['15628523', 'Male', '35', '39000', '0']
# The label for test instance: 0
# The test instance: ['15708196', 'Male', '49', '74000', '0']
# The label for test instance: 0
# The test instance: ['15735549', 'Female', '39', '134000', '1']
# The label for test instance: 1
# The test instance: ['15809347', 'Female', '41', '71000', '0']
# The label for test instance: 0
# The test instance: ['15660866', 'Female', '58', '101000', '1']
# The label for test instance: 1
# The test instance: ['15766609', 'Female', '47', '47000', '0']
# The label for test instance: 0
# The test instance: ['15654230', 'Female', '55', '130000', '1']
# The label for test instance: 1
# The test instance: ['15794566', 'Female', '52', '114000', '0']
# The label for test instance: 0
# The test instance: ['15800890', 'Female', '40', '142000', '1']
# The label for test instance: 1
# The test instance: ['15697424', 'Female', '46', '22000', '0']
# The label for test instance: 0
# The test instance: ['15724536', 'Female', '48', '96000', '1']
# The label for test instance: 1
# The test instance: ['15735878', 'Male', '52', '150000', '1']
# The label for test instance: 1
# The test instance: ['15707596', 'Female', '59', '42000', '0']
# The label for test instance: 0
# The test instance: ['15657163', 'Male', '35', '58000', '0']
# The label for test instance: 0
# The test instance: ['15622478', 'Male', '47', '43000', '0']
# The label for test instance: 0
# The test instance: ['15779529', 'Female', '60', '108000', '1']
# The label for test instance: 1
# The test instance: ['15636023', 'Male', '49', '65000', '0']
# The label for test instance: 0
# The test instance: ['15582066', 'Male', '40', '78000', '0']
# The label for test instance: 0
# The test instance: ['15666675', 'Female', '46', '96000', '0']
# The label for test instance: 0
# The test instance: ['15732987', 'Male', '59', '143000', '1']
# The label for test instance: 1
# The test instance: ['15789432', 'Female', '41', '80000', '0']
# The label for test instance: 0
# The test instance: ['15663161', 'Male', '35', '91000', '1']
# The label for test instance: 1
# The test instance: ['15694879', 'Male', '37', '144000', '1']
# The label for test instance: 1
# The test instance: ['15593715', 'Male', '60', '102000', '1']
# The label for test instance: 1
# The test instance: ['15575002', 'Female', '35', '60000', '0']
# The label for test instance: 0
# The test instance: ['15622171', 'Male', '37', '53000', '0']
# The label for test instance: 0
# The test instance: ['15795224', 'Female', '36', '126000', '1']
# The label for test instance: 1
# The test instance: ['15685346', 'Male', '56', '133000', '1']
# The label for test instance: 1
# The test instance: ['15691808', 'Female', '40', '72000', '0']
# The label for test instance: 0
# The test instance: ['15721007', 'Female', '42', '80000', '1']
# The label for test instance: 1
# The test instance: ['15794253', 'Female', '35', '147000', '1']
# The label for test instance: 1
# The test instance: ['15694453', 'Male', '39', '42000', '0']
# The label for test instance: 0
# The test instance: ['15813113', 'Male', '40', '107000', '1']
# The label for test instance: 1
# The test instance: ['15614187', 'Male', '49', '86000', '1']
# The label for test instance: 1
# The test instance: ['15619407', 'Female', '38', '112000', '0']
# The label for test instance: 0
# The test instance: ['15646227', 'Male', '46', '79000', '1']
# The label for test instance: 1
# The test instance: ['15660541', 'Male', '40', '57000', '0']
# The label for test instance: 0
# The test instance: ['15753874', 'Female', '37', '80000', '0']
# The label for test instance: 0
# The test instance: ['15617877', 'Female', '46', '82000', '0']
# The label for test instance: 0
# The test instance: ['15772073', 'Female', '53', '143000', '1']
# The label for test instance: 1
# The test instance: ['15701537', 'Male', '42', '149000', '1']
# The label for test instance: 1
# The test instance: ['15736228', 'Male', '38', '59000', '0']
# The label for test instance: 0
# The test instance: ['15780572', 'Female', '50', '88000', '1']
# The label for test instance: 1
# The test instance: ['15769596', 'Female', '56', '104000', '1']
# The label for test instance: 1
# The test instance: ['15586996', 'Female', '41', '72000', '0']
# The label for test instance: 0
# The test instance: ['15722061', 'Female', '51', '146000', '1']
# The label for test instance: 1
# The test instance: ['15638003', 'Female', '35', '50000', '0']
# The label for test instance: 0
# The test instance: ['15775590', 'Female', '57', '122000', '1']
# The label for test instance: 1
# The test instance: ['15730688', 'Male', '41', '52000', '0']
# The label for test instance: 0
# The test instance: ['15753102', 'Female', '35', '97000', '1']
# The label for test instance: 1
# The test instance: ['15810075', 'Female', '44', '39000', '0']
# The label for test instance: 0
# The test instance: ['15723373', 'Male', '37', '52000', '0']
# The label for test instance: 0
# The test instance: ['15795298', 'Female', '48', '134000', '1']
# The label for test instance: 1
# The test instance: ['15584320', 'Female', '37', '146000', '1']
# The label for test instance: 1
# The test instance: ['15724161', 'Female', '50', '44000', '0']
# The label for test instance: 0
# The test instance: ['15750056', 'Female', '52', '90000', '1']
# The label for test instance: 1
# The test instance: ['15609637', 'Female', '41', '72000', '0']
# The label for test instance: 0
# The test instance: ['15794493', 'Male', '40', '57000', '0']
# The label for test instance: 0
# The test instance: ['15569641', 'Female', '58', '95000', '1']
# The label for test instance: 1
# The test instance: ['15815236', 'Female', '45', '131000', '1']
# The label for test instance: 1
# The test instance: ['15811177', 'Female', '35', '77000', '0']
# The label for test instance: 0
# The test instance: ['15680587', 'Male', '36', '144000', '1']
# The label for test instance: 1
# The test instance: ['15672821', 'Female', '55', '125000', '1']
# The label for test instance: 1
# The test instance: ['15767681', 'Female', '35', '72000', '0']
# The label for test instance: 0
# The test instance: ['15600379', 'Male', '48', '90000', '1']
# The label for test instance: 1
# The test instance: ['15801336', 'Female', '42', '108000', '1']
# The label for test instance: 1
# The test instance: ['15721592', 'Male', '40', '75000', '0']
# The label for test instance: 0
# The test instance: ['15581282', 'Male', '37', '74000', '0']
# The label for test instance: 0
# The test instance: ['15746203', 'Female', '47', '144000', '1']
# The label for test instance: 1
# The test instance: ['15583137', 'Male', '40', '61000', '0']
# The label for test instance: 0
# The test instance: ['15680752', 'Female', '43', '133000', '0']
# The label for test instance: 0
# The test instance: ['15688172', 'Female', '59', '76000', '1']
# The label for test instance: 1
# The test instance: ['15791373', 'Male', '60', '42000', '1']
# The label for test instance: 1
# The test instance: ['15589449', 'Male', '39', '106000', '1']
# The label for test instance: 1
# The test instance: ['15692819', 'Female', '57', '26000', '1']
# The label for test instance: 1
# The test instance: ['15727467', 'Male', '57', '74000', '1']
# The label for test instance: 1
# The test instance: ['15734312', 'Male', '38', '71000', '0']
# The label for test instance: 0
# The test instance: ['15764604', 'Male', '49', '88000', '1']
# The label for test instance: 1
# The test instance: ['15613014', 'Female', '52', '38000', '1']
# The label for test instance: 1
# The test instance: ['15759684', 'Female', '50', '36000', '1']
# The label for test instance: 1
# The test instance: ['15609669', 'Female', '59', '88000', '1']
# The label for test instance: 1
# The test instance: ['15685536', 'Male', '35', '61000', '0']
# The label for test instance: 0
# The test instance: ['15750447', 'Male', '37', '70000', '1']
# The label for test instance: 1
# The test instance: ['15663249', 'Female', '52', '21000', '1']
# The label for test instance: 1
# The test instance: ['15638646', 'Male', '48', '141000', '0']
# The label for test instance: 0
# The test instance: ['15734161', 'Female', '37', '93000', '1']
# The label for test instance: 1
# The test instance: ['15631070', 'Female', '37', '62000', '0']
# The label for test instance: 0
# The test instance: ['15761950', 'Female', '48', '138000', '1']
# The label for test instance: 1
# The test instance: ['15649668', 'Male', '41', '79000', '0']
# The label for test instance: 0
# The test instance: ['15713912', 'Female', '37', '78000', '1']
# The label for test instance: 1
# The test instance: ['15586757', 'Male', '39', '134000', '1']
# The label for test instance: 1
# The test instance: ['15596522', 'Male', '49', '89000', '1']
# The label for test instance: 1
# The test instance: ['15625395', 'Male', '55', '39000', '1']
# The label for test instance: 1
# The test instance: ['15760570', 'Male', '37', '77000', '0']
# The label for test instance: 0
# The test instance: ['15566689', 'Female', '35', '57000', '0']
# The label for test instance: 0
# The test instance: ['15725794', 'Female', '36', '63000', '0']
# The label for test instance: 0
# The test instance: ['15673539', 'Male', '42', '73000', '1']
# The label for test instance: 1
# The test instance: ['15705298', 'Female', '43', '112000', '1']
# The label for test instance: 1
# The test instance: ['15675791', 'Male', '45', '79000', '0']
# The label for test instance: 0
# The test instance: ['15747043', 'Male', '46', '117000', '1']
# The label for test instance: 1
# The test instance: ['15736397', 'Female', '58', '38000', '1']
# The label for test instance: 1
# The test instance: ['15678201', 'Male', '48', '74000', '1']
# The label for test instance: 1
# The test instance: ['15720745', 'Female', '37', '137000', '1']
# The label for test instance: 1
# The test instance: ['15637593', 'Male', '37', '79000', '1']
# The label for test instance: 1
# The test instance: ['15598070', 'Female', '40', '60000', '0']
# The label for test instance: 0
# The test instance: ['15787550', 'Male', '42', '54000', '0']
# The label for test instance: 0
# The test instance: ['15603942', 'Female', '51', '134000', '0']
# The label for test instance: 0
# The test instance: ['15733973', 'Female', '47', '113000', '1']
# The label for test instance: 1
# The test instance: ['15596761', 'Male', '36', '125000', '1']
# The label for test instance: 1
# The test instance: ['15652400', 'Female', '38', '50000', '0']
# The label for test instance: 0
# The test instance: ['15717893', 'Female', '42', '70000', '0']
# The label for test instance: 0
# The test instance: ['15622585', 'Male', '39', '96000', '1']
# The label for test instance: 1
# The test instance: ['15733964', 'Female', '38', '50000', '0']
# The label for test instance: 0
# The test instance: ['15753861', 'Female', '49', '141000', '1']
# The label for test instance: 1
# The test instance: ['15747097', 'Female', '39', '79000', '0']
# The label for test instance: 0
# The test instance: ['15594762', 'Female', '39', '75000', '1']
# The label for test instance: 1
# The test instance: ['15667417', 'Female', '54', '104000', '1']
# The label for test instance: 1
# The test instance: ['15684861', 'Male', '35', '55000', '0']
# The label for test instance: 0
# The test instance: ['15742204', 'Male', '45', '32000', '1']
# The label for test instance: 1
# The test instance: ['15623502', 'Male', '36', '60000', '0']
# The label for test instance: 0
# The test instance: ['15774872', 'Female', '52', '138000', '1']
# The label for test instance: 1
# The test instance: ['15611191', 'Female', '53', '82000', '1']
# The label for test instance: 1
# The test instance: ['15674331', 'Male', '41', '52000', '0']
# The label for test instance: 0
# The test instance: ['15619465', 'Female', '48', '30000', '1']
# The label for test instance: 1
# The test instance: ['15575247', 'Female', '48', '131000', '1']
# The label for test instance: 1
# The test instance: ['15695679', 'Female', '41', '60000', '0']
# The label for test instance: 0
# The test instance: ['15713463', 'Male', '41', '72000', '0']
# The label for test instance: 0
# The test instance: ['15785170', 'Female', '42', '75000', '0']
# The label for test instance: 0
# The test instance: ['15796351', 'Male', '36', '118000', '1']
# The label for test instance: 1
# The test instance: ['15639576', 'Female', '47', '107000', '1']
# The label for test instance: 1
# The test instance: ['15693264', 'Male', '38', '51000', '0']
# The label for test instance: 0
# The test instance: ['15589715', 'Female', '48', '119000', '1']
# The label for test instance: 1
# The test instance: ['15769902', 'Male', '42', '65000', '0']
# The label for test instance: 0
# The test instance: ['15587177', 'Male', '40', '65000', '0']
# The label for test instance: 0
# The test instance: ['15814553', 'Male', '57', '60000', '1']
# The label for test instance: 1
# The test instance: ['15601550', 'Female', '36', '54000', '0']
# The label for test instance: 0
# The test instance: ['15664907', 'Male', '58', '144000', '1']
# The label for test instance: 1
# The test instance: ['15612465', 'Male', '35', '79000', '0']
# The label for test instance: 0
# The test instance: ['15810800', 'Female', '38', '55000', '0']
# The label for test instance: 0
# The test instance: ['15665760', 'Male', '39', '122000', '1']
# The label for test instance: 1
# The test instance: ['15588080', 'Female', '53', '104000', '1']
# The label for test instance: 1
# The test instance: ['15776844', 'Male', '35', '75000', '0']
# The label for test instance: 0
# The test instance: ['15717560', 'Female', '38', '65000', '0']
# The label for test instance: 0
# The test instance: ['15629739', 'Female', '47', '51000', '1']
# The label for test instance: 1
# The test instance: ['15729908', 'Male', '47', '105000', '1']
# The label for test instance: 1
# The test instance: ['15716781', 'Female', '41', '63000', '0']
# The label for test instance: 0
# The test instance: ['15646936', 'Male', '53', '72000', '1']
# The label for test instance: 1
# The test instance: ['15768151', 'Female', '54', '108000', '1']
# The label for test instance: 1
# The test instance: ['15579212', 'Male', '39', '77000', '0']
# The label for test instance: 0
# The test instance: ['15721835', 'Male', '38', '61000', '0']
# The label for test instance: 0
# The test instance: ['15800515', 'Female', '38', '113000', '1']
# The label for test instance: 1
# The test instance: ['15591279', 'Male', '37', '75000', '0']
# The label for test instance: 0
# The test instance: ['15587419', 'Female', '42', '90000', '1']
# The label for test instance: 1
# The test instance: ['15750335', 'Female', '37', '57000', '0']
# The label for test instance: 0
# The test instance: ['15699619', 'Male', '36', '99000', '1']
# The label for test instance: 1
# The test instance: ['15606472', 'Male', '60', '34000', '1']
# The label for test instance: 1
# The test instance: ['15778368', 'Male', '54', '70000', '1']
# The label for test instance: 1
# The test instance: ['15671387', 'Female', '41', '72000', '0']
# The label for test instance: 0
# The test instance: ['15573926', 'Male', '40', '71000', '1']
# The label for test instance: 1
# The test instance: ['15709183', 'Male', '42', '54000', '0']
# The label for test instance: 0
# The test instance: ['15577514', 'Male', '43', '129000', '1']
# The label for test instance: 1
# The test instance: ['15778830', 'Female', '53', '34000', '1']
# The label for test instance: 1
# The test instance: ['15768072', 'Female', '47', '50000', '1']
# The label for test instance: 1
# The test instance: ['15768293', 'Female', '42', '79000', '0']
# The label for test instance: 0
# The test instance: ['15654456', 'Male', '42', '104000', '1']
# The label for test instance: 1
# The test instance: ['15807525', 'Female', '59', '29000', '1']
# The label for test instance: 1
# The test instance: ['15574372', 'Female', '58', '47000', '1']
# The label for test instance: 1
# The test instance: ['15671249', 'Male', '46', '88000', '1']
# The label for test instance: 1
# The test instance: ['15779744', 'Male', '38', '71000', '0']
# The label for test instance: 0
# The test instance: ['15624755', 'Female', '54', '26000', '1']
# The label for test instance: 1
# The test instance: ['15611430', 'Female', '60', '46000', '1']
# The label for test instance: 1
# The test instance: ['15774744', 'Male', '60', '83000', '1']
# The label for test instance: 1
# The test instance: ['15629885', 'Female', '39', '73000', '0']
# The label for test instance: 0
# The test instance: ['15708791', 'Male', '59', '130000', '1']
# The label for test instance: 1
# The test instance: ['15793890', 'Female', '37', '80000', '0']
# The label for test instance: 0
# The test instance: ['15646091', 'Female', '46', '32000', '1']
# The label for test instance: 1
# The test instance: ['15596984', 'Female', '46', '74000', '0']
# The label for test instance: 0
# The test instance: ['15800215', 'Female', '42', '53000', '0']
# The label for test instance: 0
# The test instance: ['15577806', 'Male', '41', '87000', '1']
# The label for test instance: 1
# The test instance: ['15749381', 'Female', '58', '23000', '1']
# The label for test instance: 1
# The test instance: ['15683758', 'Male', '42', '64000', '0']
# The label for test instance: 0
# The test instance: ['15670615', 'Male', '48', '33000', '1']
# The label for test instance: 1
# The test instance: ['15715622', 'Female', '44', '139000', '1']
# The label for test instance: 1
# The test instance: ['15707634', 'Male', '49', '28000', '1']
# The label for test instance: 1
# The test instance: ['15806901', 'Female', '57', '33000', '1']
# The label for test instance: 1
# The test instance: ['15775335', 'Male', '56', '60000', '1']
# The label for test instance: 1
# The test instance: ['15724150', 'Female', '49', '39000', '1']
# The label for test instance: 1
# The test instance: ['15627220', 'Male', '39', '71000', '0']
# The label for test instance: 0
# The test instance: ['15672330', 'Male', '47', '34000', '1']
# The label for test instance: 1
# The test instance: ['15668521', 'Female', '48', '35000', '1']
# The label for test instance: 1
# The test instance: ['15807837', 'Male', '48', '33000', '1']
# The label for test instance: 1
# The test instance: ['15592570', 'Male', '47', '23000', '1']
# The label for test instance: 1
# The test instance: ['15748589', 'Female', '45', '45000', '1']
# The label for test instance: 1
# The test instance: ['15635893', 'Male', '60', '42000', '1']
# The label for test instance: 1
# The test instance: ['15757632', 'Female', '39', '59000', '0']
# The label for test instance: 0
# The test instance: ['15691863', 'Female', '46', '41000', '1']
# The label for test instance: 1
# The test instance: ['15706071', 'Male', '51', '23000', '1']
# The label for test instance: 1
# The test instance: ['15654296', 'Female', '50', '20000', '1']
# The label for test instance: 1
# The test instance: ['15755018', 'Male', '36', '33000', '0']
# The label for test instance: 0
# The test instance: ['15594041', 'Female', '49', '36000', '1']
# The label for test instance: 1
